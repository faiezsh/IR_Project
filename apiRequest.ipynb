# %%
import requests

url = "http://127.0.0.1:5000/suggest/train/rad"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
s=response.text.replace('[',"")
s=s.replace(']',"")
s=s.split(',')
for res in s:
    print(res)
# Out:
# {"res": "rad"
#  "radcliffe"
#  "radi"
#  "radio"
#  "radios"
#  "radioshack"
#  "radiostation"
#  "radio/tv"
#  "radio/music"
#  "radio/739"
#  "radioactive"
#  "radioactively"
#  "radioactivity"
#  "radiomen"
#  "radiometry"
#  "radiometric"
#  "radioisotope"
#  "radioisotopes"
#  "radiograph"
#  "radiographing"
#  "radiographic"
#  "radiographs"
#  "radiography"
#  "radiographers"
#  "radio-CD"
#  "radio-opaque"
#  "radio-type"
#  "radio-waves"
#  "radio-controlled"
#  "radio-iodine"
#  "radio-ablation"
#  "radio-ulna"
#  "radiology"
#  "radiologist"
#  "radiologists"
#  "radiologic"
#  "radiological"
#  "radiolucent"
#  "radiolgogy"
#  "radiodurans\u2014that"
#  "radiotherapy"
#  "radiotowers"
#  "radionuclide"
#  "radionuclides"
#  "radioed"
#  "radiocarbon"
#  "radioctive"
#  "radioctivity"
#  "radio."
#  "radio.intercom"
#  "radiopathy"
#  "radious"
#  "radiowaves"
#  "radiowaves."
#  "radior"
#  "radioreactive"
#  "radiate"
#  "radiates"
#  "radiated"
#  "radiater"
# ...
